# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/Shareddrives/CSE544_Project/flight_dataset/LA_2021
# !ls
# Out:
# /content/drive/Shareddrives/CSE544_Project/flight_dataset/LA_2021
# Apr.csv  Dec.csv  Jan.csv   June.csv		    Mar.csv  Nov.csv  Sept.csv
# Aug.csv  Feb.csv  July.csv  LA_preprocessing.ipynb  May.csv  Oct.csv

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os
import glob

# %%
path = os.getcwd()
csv_files = glob.glob(os.path.join(path, "*.csv"))
df = pd.concat(map(pd.read_csv, csv_files), ignore_index = True)
df = df[df['ORIGIN_STATE_ABR'] == 'LA']
df
# Out:
#         YEAR  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK  \
# 17      2021        1      1            23            6
# 18      2021        1      1            23            6
# 19      2021        1      1            23            6
# 20      2021        1      1            23            6
# 21      2021        1      1            23            6
# ...      ...      ...    ...           ...          ...
# 111427  2021        4     12            26            7
# 111429  2021        4     12            27            1
# 111431  2021        4     12            28            2
# 111433  2021        4     12            29            3
# 111435  2021        4     12            30            4
#
#                        FL_DATE OP_UNIQUE_CARRIER  OP_CARRIER_FL_NUM  \
# 17       1/23/2021 12:00:00 AM                WN               3612
# 18       1/23/2021 12:00:00 AM                WN               4245
# 19       1/23/2021 12:00:00 AM                WN               4560
# ...

# %%
df_cancelled_month = df[['CANCELLED','CANCELLATION_CODE','MONTH']]
# df_cancelled_month = df_cancelled_month.groupby(['MONTH']).sum()
df_cancelled_month.CANCELLATION_CODE.value_counts()
# Out:
# B    1846
# A     402
# C     236
# D       2
# Name: CANCELLATION_CODE, dtype: int64
